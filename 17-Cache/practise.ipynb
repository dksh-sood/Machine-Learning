# %% [markdown]
# ### temperature conversion
# ### password strength check
# ### calculate total cost of items in a shopping cart
# ### check if a string is pallindrome
# ### calculate the faactorial of a number using recursion
# ### a function to read a file and count the freq of each word
# ### valid email addres

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
a = pd.Series([1,2,3,4,5])
b = pd.Series([6,7,8,9,10])
# print(a)
print(a + 2)
print(b + 2)
# Out:
# 0    3
# 1    4
# 2    5
# 3    6
# 4    7
# dtype: int64
# 0     8
# 1     9
# 2    10
# 3    11
# 4    12
# dtype: int64
