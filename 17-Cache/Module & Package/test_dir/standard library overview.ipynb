# %% [markdown]
# ## Standard library Overview

# %% [markdown]
# used for vast collection of modules and packages that come bundled with python.
# providing a wide range of functionalities.

# %%
import array
arr = array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import random
print(random.randint(1,10))
print(random.choice(['a','b','c','d']))
# Out:
# 4
# c

# %%
# file and directory access
import os
print(os.getcwd())
# Out:
# c:\Users\91742\OneDrive\Desktop\Machine Learning\Module & Package

# %%
os.mkdir('test_dir') # make dir in the file

# %%
# high level operations on files and collection of files
import shutil
shutil.copyfile('source.txt','destination.txt') # copy the same file
# Out:
# 'destination.txt'

# %%
## data serialization
import json
data = {'name':'krish','age':25}

json_str = json.dumps(data) # convert into str
print(json_str)
print(type(json_str))

parsed_data = json.loads(json_str) # convert int dict
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "krish", "age": 25}
# <class 'str'>
# {'name': 'krish', 'age': 25}
# <class 'dict'>

# %%
## csv

import csv

with open('example.csv',mode='w',newline='') as file:
  writer = csv.writer(file)
  writer.writerow(['name','age'])
  writer.writerow(['daksh',21])

with open('example.csv',mode='r') as file:
  reader = csv.reader(file)
  for row in reader:
    print(row)
# Out:
# ['name', 'age']
# ['daksh', '21']

# %%
# date time
from datetime import datetime , timedelta

now = datetime.now()
print(now)

yesterday = now - timedelta(days=1)
print(yesterday)
# Out:
# 2025-08-03 22:07:32.099718
# 2025-08-02 22:07:32.099718

# %%
##time
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1754239107.1807377
# 1754239109.1820056

# %%
# regular expression
import re
pattern = r'\d+' # specific for digit 
text = 'there are 123 apples'
match = re.search(pattern,text)
print(match.group())
# Out:
# 123
