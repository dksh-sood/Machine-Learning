# %% [markdown]
# ## Module and Package

# %%
from math import *
print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
import numpy as np
np.maths(1,2,3,4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 import numpy as np
# ----> 2 np.maths(1,2,3,4)
#
# File c:\Users\91742\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\__init__.py:427, in __getattr__(attr)
#     424     import numpy.char as char
#     425     return char.chararray
# --> 427 raise AttributeError("module {!r} has no attribute "
#     428                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'maths'

# %%
from package.maths import addition
addition(2,3)
# Out:
# 5

# %%
from package import maths
addition(2,3)
