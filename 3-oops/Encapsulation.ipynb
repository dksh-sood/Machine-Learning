# %% [markdown]
# ## Encapsulation and Abstraction
# -> two fundamental princlple of oops that helps in design robust, maintainable and resuable code.
# ## encapsulation
# -> involves bundling data and methods that operates on the data within a single unit
# ## abstraction
# -> involves hiding comples implementation details and exposing only necssary features

# %% [markdown]
# ## Encapsulation
# -> is the concept of wrapping data (variable) and methods(functions) together as a single unit. it restricts direct access of some of the objects components , which is means of preventing accidental interference and misuse of data

# %%
## encapsulation with getter and setter methods
## public , protected, private variables  or access modifiers

class Person:
  def __init__(self,name,age):
    self.name=name ## public variable
    self.age = age ## public variable 

def get_name(person):
    return person.name

person = Person("daksh",21)
get_name(person) # able to access the outside the class
# Out:
# 'daksh'

# %%
dir(person) # give all public variable
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age',
#  'get_name',
#  'name']

# %%
## "__" is uded to make the private variable 
class Person:
  def __init__(self,name,age,gender):
    self.__name=name ## private variable
    self.__age = age ## private variable 
    self.gender = gender ## public vairable

# %%
## not run becuz its a private variable 
def get_name(person):
  return person.__name
  #return person._Person__name # not a good way
  
person = Person("daksh",21,"male")
get_name(person)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 7
#       4   #return person._Person__name # not a good way
#       6 person = Person("daksh",21,"male")
# ----> 7 get_name(person)
#
# Cell In[18], line 3, in get_name(person)
#       2 def get_name(person):
# ----> 3   return person.__name
#
# AttributeError: 'Person' object has no attribute '__name'

# %%
person = Person("daksh",21,"male")
dir(person) # variable now gonna private
# Out:
# ['_Person__age',
#  '_Person__name',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'gender']

# %%
## "_" protected variable -> not acces from the  outside the class but can we access from derived class
class Person:
  def __init__(self,name,age,gender):
    self._name=name ## protected variable
    self._age = age ## protected variable 
    self.gender = gender 

class Employee(Person):
  def __init__(self,name,age,gender):
    super().__init__(name,age,gender)

employee = Employee("daksh",21,"Male")
print(employee._name)
# Out:
# daksh

# %%
## Encapsulation with getter and setter methods
class Person:
  def __init__(self,name,age):
    self.__name = name # private access modifier or variabvle
    self.__age = age ## private variable

  ##getter method for name
  def get_name(self):
    return self.__name
  
  ## setter -> change any value that we gives
  def set_name(self,name):
    self.__name=name
  
  ## getter method for age 
  def get_age(self):
    return self.__age
  
  ## setter method for age 
  def set_age(self,age):
    if age>0:
      self.__age=age
    else:
      print("age cannot be negative.")


person = Person("daksh",21)

## access and modify private variable using getter and setter 

print(person.get_name())
print(person.get_age())


person.set_age(32)
print(person.get_age())

person.set_age(-5)
# Out:
# daksh
# 21
# 32
# age cannot be negative.
