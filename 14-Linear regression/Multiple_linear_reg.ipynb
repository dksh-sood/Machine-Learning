# %% [markdown]
# # Index Price: a measure of how prices change over a period of time

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df_index = pd.read_csv('./DATA/economic_index.csv')

# %%
df_index.head()
# Out:
#    Unnamed: 0  year  month  interest_rate  unemployment_rate  index_price
# 0           0  2017     12           2.75                5.3         1464
# 1           1  2017     11           2.50                5.3         1394
# 2           2  2017     10           2.50                5.3         1357
# 3           3  2017      9           2.50                5.3         1293
# 4           4  2017      8           2.50                5.4         1256

# %%
# droped unneccessary columns
df_index.drop(columns=['Unnamed: 0','year','month'],axis=1,inplace=True)

# %%
df_index.head()
# Out:
#    interest_rate  unemployment_rate  index_price
# 0           2.75                5.3         1464
# 1           2.50                5.3         1394
# 2           2.50                5.3         1357
# 3           2.50                5.3         1293
# 4           2.50                5.4         1256

# %%
##checking the null value
df_index.isnull().sum()
# Out:
# interest_rate        0
# unemployment_rate    0
# index_price          0
# dtype: int64

# %%
## lets do some visualization
import seaborn as sns
sns.pairplot(df_index)

# %%
df_index.corr()
# Out:
#                    interest_rate  unemployment_rate  index_price
# interest_rate           1.000000          -0.925814     0.935793
# unemployment_rate      -0.925814           1.000000    -0.922338
# index_price             0.935793          -0.922338     1.000000

# %%
## visualize the datapoints more clearly
plt.scatter(df_index['interest_rate'],df_index['unemployment_rate'],color='r')
plt.xlabel("Interest Rate")
plt.ylabel("Unemployment rate")
# Out:
# Text(0, 0.5, 'Unemployment rate')

# %%
## independent and dependent feature \
X=df_index.iloc[:,:-1] # select all except last col
y=df_index.iloc[:,-1] # select last col

# %%
X.head()
# Out:
#    interest_rate  unemployment_rate
# 0           2.75                5.3
# 1           2.50                5.3
# 2           2.50                5.3
# 3           2.50                5.3
# 4           2.50                5.4

# %%
y
# Out:
# 0     1464
# 1     1394
# 2     1357
# 3     1293
# 4     1256
# 5     1254
# 6     1234
# 7     1195
# 8     1159
# 9     1167
# 10    1130
# 11    1075
# 12    1047
# 13     965
# 14     943
# 15     958
# 16     971
# 17     949
# 18     884
# 19     866
# 20     876
# 21     822
# 22     704
# 23     719
# Name: index_price, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
import seaborn as sns
sns.regplot(x='interest_rate', y='index_price', data=df_index)
# Out:
# <Axes: xlabel='interest_rate', ylabel='index_price'>

# %%
sns.regplot(x='unemployment_rate', y='interest_rate', data=df_index)
# Out:
# <Axes: xlabel='unemployment_rate', ylabel='interest_rate'>

# %%
sns.regplot(x='index_price', y='unemployment_rate', data=df_index)
# Out:
# <Axes: xlabel='index_price', ylabel='unemployment_rate'>

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
X_train
# Out:
# array([[-0.90115511,  0.37908503],
#        [ 1.31077107, -1.48187786],
#        [-0.90115511,  1.30956648],
#        [ 1.31077107, -0.55139641],
#        [ 1.31077107, -1.48187786],
#        [-0.16384638,  0.68924552],
#        [-0.90115511,  0.999406  ],
#        [ 1.31077107, -1.48187786],
#        [ 1.31077107, -1.17171738],
#        [-0.90115511,  1.30956648],
#        [-0.90115511,  0.999406  ],
#        [-0.90115511,  0.37908503],
#        [-0.90115511,  0.999406  ],
#        [ 0.57346234, -0.8615569 ],
#        [-0.16384638, -0.24123593],
#        [-0.90115511,  0.06892455],
#        [-0.90115511,  0.999406  ],
#        [ 1.31077107, -0.8615569 ]])

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
## Cross Validation
from sklearn.model_selection import cross_val_score
validation_score=cross_val_score(regression,X_train,y_train,scoring='neg_mean_squared_error',cv=3)

# %%
validation_score
# Out:
# array([-4921.61331265, -7686.87497294, -5135.9962549 ])

# %%
np.mean(validation_score) #-> get mean nmse-> jitna kum utna mst
# Out:
# np.float64(-5914.828180162386)

# %%
##Prediction
y_pred=regression.predict(X_test)

# %%
y_pred
# Out:
# array([1204.22770398,  821.65051903, 1406.51300368,  857.70889608,
#         994.90992298, 1168.16932693])

# %%
## Perfromance metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
rmse=np.sqrt(mse)
print("mse :",mse)
print("mae :",mae)
print("rmse:",rmse)
# Out:
# mse : 5793.762887712569
# mae : 59.935781523235484
# rmse: 76.11677139574805

# %% [markdown]
# # Rsquare

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
print(score)
# Out:
# 0.8278978091457145

# %% [markdown]
# # Adjusted R2

# %%
print(1-(1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1))
# Out:
# 0.7131630152428576

# %% [markdown]
# ## Assumption

# %%
plt.scatter(y_test,y_pred)

# %%
residuals=y_test-y_pred
print(residuals)
# Out:
# 8     -45.227704
# 16    149.349481
# 0      57.486996
# 18     26.291104
# 11     80.090077
# 9      -1.169327
# Name: index_price, dtype: float64

# %%
sns.displot(residuals,kind='kde')

# %%
## scatter plot with respect to predictyions and residuals
plt.scatter(y_pred,residuals)
## uniformly distribution donot follow any patter

# %%
# OLS model
import statsmodels.api as sm

# %%
model = sm.OLS(y_train, X_train).fit()

# %%
model.summary()
# Out:
# c:\Users\91742\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=18 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:            index_price   R-squared (uncentered):                   0.035
# Model:                            OLS   Adj. R-squared (uncentered):             -0.086
# Method:                 Least Squares   F-statistic:                             0.2880
# Date:                Tue, 02 Dec 2025   Prob (F-statistic):                       0.754
# Time:                        18:56:20   Log-Likelihood:                         -150.85
# No. Observations:                  18   AIC:                                      305.7
# ...

# %%
print(regression.coef_)
# Out:
# [  88.27275507 -116.25716066]

# %%
print(regression.intercept_)
# Out:
# 1053.4444444444443
