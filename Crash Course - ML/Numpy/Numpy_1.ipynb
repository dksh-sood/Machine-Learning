# %%
import numpy as np
x = np.array([1,2,3,4,5])
x
print(type(x))
print("the dimension of array is-->" ,x.ndim)
# Out:
# <class 'numpy.ndarray'>
# the dimension of array is--> 1

# %%
#find time of execution for single line
# %timeit [i**4 for i in range(1,9)]
# Out:
# 920 ns ± 48.6 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
import numpy as fuck
# %timeit fuck.arange(1,9)**4
# Out:
# 2.46 μs ± 108 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
l =[]
for i in range(1,4):
    a = int(input("enter the number-->"))
    l.append(a)
print(np.array(l))
# Out:
# [12 13 14]

# %%
arn = np.array([1,2,3,4],ndmin=10)
print(arn)
print(arn.ndim)
# Out:
# [[[[[[[[[[1 2 3 4]]]]]]]]]]
# 10
