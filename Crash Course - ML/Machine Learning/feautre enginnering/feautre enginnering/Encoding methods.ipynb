# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder ,OneHotEncoder 
from category_encoders import BinaryEncoder ,TargetEncoder, HashingEncoder
# Sample data
data = {'color': ['red', 'blue', 'green', 'blue', 'red', 'green', 'green'],
        'price': [22, 19, 15, 20, 23, 18, 17]}
df = pd.DataFrame(data)

# # Label Encoding
# label_encoder = LabelEncoder()
# df['color_label'] = label_encoder.fit_transform(df['color'])
# print("label")

# #One-Hot Encoding
# onehot_encoder = OneHotEncoder()
# color_encoded = onehot_encoder.fit_transform(df[['color']]).toarray()
# df = df.join(pd.DataFrame(color_encoded, columns=onehot_encoder.get_feature_names_out(['color'])))

# # Binary Encoding
# binary_encoder = BinaryEncoder()
# df_binary = binary_encoder.fit_transform(df[['color']])
# print(df_binary)

# # Target Encoding
# target_encoder = TargetEncoder()
# df['color_target'] = target_encoder.fit_transform(df['color'], df['price'])

# # Frequency Encoding
# frequency_encoding = df['color'].value_counts(normalize=True)
# df['color_frequency'] = df['color'].map(frequency_encoding)

# # Hashing Encoding
# hasher = FeatureHasher(n_features=3, input_type='string')
# hashed_features = hasher.transform(df['color']).toarray()
# df = df.join(pd.DataFrame(hashed_features, columns=[f'hash_{i}' for i in range(hashed_features.shape[1])]))

# # Leave-One-Out Encoding
# loo_encoder = LeaveOneOutEncoder()
# df['color_loo'] = loo_encoder.fit_transform(df['color'], df['price'])

# # Count Encoding
# df['color_count'] = df['color'].map(df['color'].value_counts())

# Display the dataframe with different encodings
print(df)
# Out:
#    color  price  color_frequency
# 0    red     22         0.285714
# 1   blue     19         0.285714
# 2  green     15         0.428571
# 3   blue     20         0.285714
# 4    red     23         0.285714
# 5  green     18         0.428571
# 6  green     17         0.428571
