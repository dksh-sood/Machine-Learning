# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import requests

# %%
webpage = requests.get('https://www.ambitionbox.com/list-of-companies?page=1').text

# %%
pip install parser-libraries
# Out:
# Requirement already satisfied: parser-libraries in c:\python311\lib\site-packages (3.7)
# Requirement already satisfied: pymysql in c:\python311\lib\site-packages (from parser-libraries) (1.1.1)
# Requirement already satisfied: openpy in c:\python311\lib\site-packages (from parser-libraries) (0.0.2)
# Requirement already satisfied: requests in c:\python311\lib\site-packages (from parser-libraries) (2.32.3)
# Requirement already satisfied: bs4 in c:\python311\lib\site-packages (from parser-libraries) (0.0.2)
# Requirement already satisfied: selenium in c:\python311\lib\site-packages (from parser-libraries) (4.26.0)
# Requirement already satisfied: pytelegrambotapi in c:\python311\lib\site-packages (from parser-libraries) (4.23.0)
# Requirement already satisfied: cryptography in c:\python311\lib\site-packages (from parser-libraries) (43.0.3)
# Requirement already satisfied: urllib3 in c:\python311\lib\site-packages (from parser-libraries) (2.2.2)
# Requirement already satisfied: beautifulsoup4 in c:\python311\lib\site-packages (from bs4->parser-libraries) (4.12.3)
# Requirement already satisfied: cffi>=1.12 in c:\python311\lib\site-packages (from cryptography->parser-libraries) (1.17.0)
# Requirement already satisfied: s3fs in c:\python311\lib\site-packages (from openpy->parser-libraries) (2024.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python311\lib\site-packages (from requests->parser-libraries) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\python311\lib\site-packages (from requests->parser-libraries) (3.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python311\lib\site-packages (from requests->parser-libraries) (2024.8.30)
# Requirement already satisfied: trio~=0.17 in c:\python311\lib\site-packages (from selenium->parser-libraries) (0.27.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\python311\lib\site-packages (from selenium->parser-libraries) (0.11.1)
# Requirement already satisfied: typing_extensions~=4.9 in c:\users\91742\appdata\roaming\python\python311\site-packages (from selenium->parser-libraries) (4.12.2)
# Requirement already satisfied: websocket-client~=1.8 in c:\python311\lib\site-packages (from selenium->parser-libraries) (1.8.0)
# Requirement already satisfied: pycparser in c:\python311\lib\site-packages (from cffi>=1.12->cryptography->parser-libraries) (2.22)
# Requirement already satisfied: attrs>=23.2.0 in c:\python311\lib\site-packages (from trio~=0.17->selenium->parser-libraries) (24.2.0)
# Requirement already satisfied: sortedcontainers in c:\python311\lib\site-packages (from trio~=0.17->selenium->parser-libraries) (2.4.0)
# Requirement already satisfied: outcome in c:\python311\lib\site-packages (from trio~=0.17->selenium->parser-libraries) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\python311\lib\site-packages (from trio~=0.17->selenium->parser-libraries) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in c:\python311\lib\site-packages (from trio-websocket~=0.9->selenium->parser-libraries) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\python311\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium->parser-libraries) (1.7.1)
# Requirement already satisfied: soupsieve>1.2 in c:\python311\lib\site-packages (from beautifulsoup4->bs4->parser-libraries) (2.6)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in c:\python311\lib\site-packages (from s3fs->openpy->parser-libraries) (2.15.2)
# Requirement already satisfied: fsspec==2024.10.0.* in c:\python311\lib\site-packages (from s3fs->openpy->parser-libraries) (2024.10.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\python311\lib\site-packages (from s3fs->openpy->parser-libraries) (3.10.10)
# Requirement already satisfied: botocore<1.35.37,>=1.35.16 in c:\python311\lib\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->openpy->parser-libraries) (1.35.36)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in c:\python311\lib\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->openpy->parser-libraries) (1.16.0)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in c:\python311\lib\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->openpy->parser-libraries) (0.12.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\python311\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->openpy->parser-libraries) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\python311\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->openpy->parser-libraries) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\python311\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->openpy->parser-libraries) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\python311\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->openpy->parser-libraries) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\python311\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->openpy->parser-libraries) (1.17.1)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\python311\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium->parser-libraries) (0.14.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\python311\lib\site-packages (from botocore<1.35.37,>=1.35.16->aiobotocore<3.0.0,>=2.5.4->s3fs->openpy->parser-libraries) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\91742\appdata\roaming\python\python311\site-packages (from botocore<1.35.37,>=1.35.16->aiobotocore<3.0.0,>=2.5.4->s3fs->openpy->parser-libraries) (2.9.0.post0)
# Requirement already satisfied: propcache>=0.2.0 in c:\python311\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->openpy->parser-libraries) (0.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\91742\appdata\roaming\python\python311\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.35.37,>=1.35.16->aiobotocore<3.0.0,>=2.5.4->s3fs->openpy->parser-libraries) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
soup = BeautifulSoup(webpage, 'html') # lxml , text , html is not working

# %%
soup
# Out:
# <html><head>
# <title>Access Denied</title>
# </head><body>
# <h1>Access Denied</h1>
#
# You don't have permission to access "http://www.ambitionbox.com/list-of-companies?" on this server.<p>
# Reference #18.37adce17.1731673305.3531f4c
# <p>https://errors.edgesuite.net/18.37adce17.1731673305.3531f4c</p>
# </p></body>
# </html>

# %%
soup.find_all('h1')[0].text
# Out:
# 'Access Denied'

# %%
for i in soup.find_all('h2'):
  print(i.text.strip())
