# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Titanic-Dataset.csv")
df.head()
# Out:
#    Survived     Sex   Age
# 0         0    male  22.0
# 1         1  female  38.0
# 2         1  female  26.0
# 3         1  female  35.0
# 4         0    male  35.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Sex       891 non-null    object
#  2   Age       714 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 21.0+ KB

# %%
df.describe()
# Out:
#          Survived         Age
# count  891.000000  714.000000
# mean     0.383838   29.699118
# std      0.486592   14.526497
# min      0.000000    0.420000
# 25%      0.000000   20.125000
# 50%      0.000000   28.000000
# 75%      1.000000   38.000000
# max      1.000000   80.000000

# %%
plt.scatter(x='Age',y='Survived',data=df)

# %%
from sklearn.preprocessing import LabelEncoder ,OneHotEncoder 
from category_encoders import BinaryEncoder ,TargetEncoder, HashingEncoder

# %%
# label_encoder = LabelEncoder()
# df['Survived_label'] = label_encoder.fit_transform(df['Survived'])
# print(df)

# %%
# onehot_encoder = OneHotEncoder()
# Survived_encoded = onehot_encoder.fit_transform(df[['Survived']]).toarray()
# df = df.join(pd.DataFrame(Survived_encoded, columns=onehot_encoder.get_feature_names_out(['Survived'])))
# print(df)

# %%
# target_encoder = TargetEncoder()
# df['Survived_target'] = target_encoder.fit_transform(df['Survived'], df['Sex'])

# %%
X = df.drop('Survived',axis=1)
Y = df['Survived']
df.head()
# Out:
#    Survived     Sex   Age
# 0         0    male  22.0
# 1         1  female  38.0
# 2         1  female  26.0
# 3         1  female  35.0
# 4         0    male  35.0

# %%
from sklearn.model_selection import train_test_split
X_train,Y_train,X_test,Y_test = train_test_split(X,Y,test_size=0.25,random_state=42)

# %%
X_train.head()
# Out:
#         Sex    Age
# 298    male    NaN
# 884    male  25.00
# 247  female  24.00
# 478    male  22.00
# 305    male   0.92

# %%
print(Y_train)
# Out:
#         Sex   Age
# 709    male   NaN
# 439    male  31.0
# 840    male  20.0
# 720  female   6.0
# 39   female  14.0
# ..      ...   ...
# 880  female  25.0
# 425    male   NaN
# 101    male   NaN
# 199  female  24.0
# 424    male  18.0
#
# [223 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc  = StandardScaler(
    
)

# %%
print(Y_test)
# Out:
# 709    1
# 439    0
# 840    0
# 720    1
# 39     1
#       ..
# 880    1
# 425    0
# 101    0
# 199    0
# 424    0
# Name: Survived, Length: 223, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion='entropy',random_state=0)
classifier.fit(X_test,Y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[117], line 3
#       1 from sklearn.tree import DecisionTreeClassifier
#       2 classifier = DecisionTreeClassifier(criterion='entropy',random_state=0)
# ----> 3 classifier.fit(X_test,Y_test)
#
# File c:\Python311\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Python311\Lib\site-packages\sklearn\tree\_classes.py:1009, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     978 @_fit_context(prefer_skip_nested_validation=True)
# ...
