# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Titanic.csv')
df.head()
# Out:
#    Survived     Sex   Age
# 0         0    male  22.0
# 1         1  female  38.0
# 2         1  female  26.0
# 3         1  female  35.0
# 4         0    male  35.0

# %%
x = df.drop('Survived',axis=1)
y = df['Survived']

# %%
from sklearn.preprocessing import OneHotEncoder
onehot_encoder = OneHotEncoder()
Survived_encoded = onehot_encoder.fit_transform(df[['Survived']]).toarray()
df = df.join(pd.DataFrame(Survived_encoded, columns=onehot_encoder.get_feature_names_out(['Survived'])))
print(df)
# Out:
#      Survived     Sex   Age  Survived_0  Survived_1
# 0           0    male  22.0         1.0         0.0
# 1           1  female  38.0         0.0         1.0
# 2           1  female  26.0         0.0         1.0
# 3           1  female  35.0         0.0         1.0
# 4           0    male  35.0         1.0         0.0
# ..        ...     ...   ...         ...         ...
# 886         0    male  27.0         1.0         0.0
# 887         1  female  19.0         0.0         1.0
# 888         0  female   NaN         1.0         0.0
# 889         1    male  26.0         0.0         1.0
# 890         0    male  32.0         1.0         0.0
#
# [891 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
x_test,y_tets,x_train,y_train = train_test_split(x,y,random_state=42,test_size=0.25)

# %%
x_train.head()
# Out:
# 298    1
# 884    0
# 247    1
# 478    0
# 305    1
# Name: Survived, dtype: int64

# %%
y_train.head()
# Out:
# 709    1
# 439    0
# 840    0
# 720    1
# 39     1
# Name: Survived, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=100,random_state=42)
model.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22472\842354758.py in ?()
#       1 from sklearn.ensemble import RandomForestClassifier
#       2 model = RandomForestClassifier(n_estimators=100,random_state=42)
# ----> 3 model.fit(x,y)
#
# c:\Python311\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# c:\Python311\Lib\site-packages\sklearn\ensemble\_forest.py in ?(self, X, y, sample_weight)
#     359         # Validate or convert input data
#     360         if issparse(y):
#     361             raise ValueError("sparse multilabel-indicator for y is not supported.")
# ...
