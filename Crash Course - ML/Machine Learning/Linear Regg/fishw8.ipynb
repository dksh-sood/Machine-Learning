# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model

# %%
df = pd.read_csv("Fishers maket.csv")
# X = df.drop('Species' , axis = 1)
# y = df['Weight']
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values
df
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1/3, random_state = 42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1/3, random_state = 42)
#
# NameError: name 'X' is not defined

# %%
print(X_train) #
# Out:
# [['Bream' 340.0 23.9 26.5 31.1 12.3778]
#  ['Perch' 85.0 17.8 19.6 20.8 5.1376]
#  ['Roach' 150.0 20.4 22.0 24.7 5.8045]
#  ['Parkki' 300.0 24.0 26.0 29.0 11.368]
#  ['Bream' 475.0 28.4 31.0 36.2 14.2628]
#  ['Smelt' 8.7 10.8 11.3 12.6 1.9782]
#  ['Pike' 430.0 35.5 38.0 40.5 7.29]
#  ['Smelt' 9.8 11.4 12.0 13.2 2.2044]
#  ['Smelt' 7.5 10.0 10.5 11.6 1.972]
#  ['Parkki' 140.0 19.0 20.7 23.2 8.5376]
#  ['Perch' 145.0 20.7 22.7 24.2 5.9532]
#  ['Perch' 150.0 21.0 23.0 24.5 5.2185]
#  ['Smelt' 6.7 9.3 9.8 10.8 1.7388]
#  ['Pike' 1250.0 52.0 56.0 59.7 10.6863]
#  ['Perch' 1100.0 40.1 43.0 45.5 12.5125]
#  ['Perch' 820.0 37.1 40.0 42.5 11.135]
#  ['Roach' 200.0 22.1 23.5 26.8 7.3968]
#  ['Perch' 188.0 22.6 24.6 26.2 6.7334]
#  ['Perch' 150.0 20.5 22.5 24.0 6.792]
#  ['Parkki' 120.0 17.5 19.0 21.3 8.3922]
#  ['Perch' 820.0 36.6 39.0 41.3 12.4313]
#  ['Perch' 250.0 25.9 28.0 29.4 7.8204]
#  ['Parkki' 200.0 21.2 23.0 25.8 10.3458]
#  ['Roach' 161.0 22.0 23.4 26.7 6.9153]
# ...

# %%
# Out:
#   Cell In[2], line 5
#     city_name = "New Delhi"
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %%
print(y_train)
# Out:
# [4.6961 3.0368 3.7544 4.234  5.1042 1.2852 4.5765 1.1484 1.16   3.2944
#  3.63   3.626  1.0476 6.9849 7.4165 6.63   4.1272 4.1658 3.624  2.9181
#  7.3514 4.2042 3.6636 3.6312 3.8352 5.0728 4.87   6.1306 7.7957 5.5695
#  5.58   3.1234 4.4968 2.9415 4.4555 1.8792 4.459  5.2785 3.1571 2.6316
#  3.6675 6.864  4.368  7.4624 5.1708 6.8684 3.624  5.1296 3.325  4.8146
#  5.1373 2.268  4.6816 3.3957 1.269  3.2928 4.3056 4.158  1.1484 3.2943
#  4.5662 5.134  4.896  5.1975 7.4934 4.335  3.1746 4.9274 4.7736 1.1659
#  7.2772 4.02   6.3705 6.1984 4.2476 6.2646 6.292  3.977  7.5958 5.376
#  6.7497 6.603  3.6835 3.555  3.0502 6.3666 1.3936 1.408  3.3216 6.0532
#  2.772  1.2772 1.2838 3.5742 6.562  6.1712 3.525  4.144  3.525  2.8217
#  5.3704 4.9594 4.335  3.4104 6.003  3.8   ]

# %%
print(X_test)
# Out:
# [['Bream' 390.0 27.6 30.0 35.0 12.67]
#  ['Roach' 0.0 19.0 20.5 22.8 6.4752]
#  ['Perch' 170.0 21.5 23.5 25.0 6.275]
#  ['Roach' 160.0 20.5 22.5 25.3 7.0334]
#  ['Perch' 556.0 32.0 34.5 36.5 10.2565]
#  ['Perch' 900.0 37.0 40.0 42.5 11.73]
#  ['Whitefish' 800.0 33.7 36.4 39.6 11.7612]
#  ['Pike' 300.0 34.8 37.3 39.8 6.2884]
#  ['Bream' 975.0 37.4 41.0 45.9 18.6354]
#  ['Perch' 115.0 19.0 21.0 22.5 5.9175]
#  ['Pike' 200.0 30.0 32.3 34.8 5.568]
#  ['Pike' 456.0 40.0 42.5 45.5 7.28]
#  ['Whitefish' 1000.0 37.3 40.0 43.5 12.354]
#  ['Perch' 1000.0 40.2 43.5 46.0 12.604]
#  ['Parkki' 60.0 14.3 15.5 17.4 6.5772]
#  ['Roach' 78.0 17.5 18.8 21.2 5.5756]
#  ['Roach' 145.0 20.5 22.0 24.3 6.6339]
#  ['Pike' 1600.0 56.0 60.0 64.0 9.6]
#  ['Perch' 130.0 19.3 21.3 22.8 6.384]
#  ['Bream' 720.0 32.0 35.0 40.6 16.3618]
#  ['Parkki' 55.0 13.5 14.7 16.5 6.8475]
#  ['Roach' 390.0 29.5 31.7 35.0 9.485]
#  ['Perch' 120.0 20.0 22.0 23.5 6.11]
#  ['Pike' 1650.0 59.0 63.4 68.0 10.812]
# ...

# %%
print(y_test)
# Out:
# [4.69   3.3516 3.725  3.8203 6.3875 7.225  6.5736 4.0198 6.7473 3.3075
#  3.3756 4.3225 6.525  8.142  2.3142 2.9044 3.5478 6.144  3.534  6.09
#  2.3265 5.355  3.4075 7.48   2.673  4.8438 5.589  4.2485 7.1064 1.38
#  5.7276 3.995  6.144  4.3844 5.2854 3.723  4.6354 5.2801 6.7408 3.525
#  6.018  2.432  3.825  5.8515 2.0672 4.239  3.906  4.144  5.1338 4.7716
#  6.3063 1.9992 1.2558]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  159 non-null    object
#  1   Weight   159 non-null    float64
#  2   Length1  159 non-null    float64
#  3   Length2  159 non-null    float64
#  4   Length3  159 non-null    float64
#  5   Height   159 non-null    float64
#  6   Width    159 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.8+ KB

# %%
df.describe()
# Out:
#             Weight     Length1     Length2     Length3      Height       Width
# count   159.000000  159.000000  159.000000  159.000000  159.000000  159.000000
# mean    398.326415   26.247170   28.415723   31.227044    8.970994    4.417486
# std     357.978317    9.996441   10.716328   11.610246    4.286208    1.685804
# min       0.000000    7.500000    8.400000    8.800000    1.728400    1.047600
# 25%     120.000000   19.050000   21.000000   23.150000    5.944800    3.385650
# 50%     273.000000   25.200000   27.300000   29.400000    7.786000    4.248500
# 75%     650.000000   32.700000   35.500000   39.650000   12.365900    5.584500
# max    1650.000000   59.000000   63.400000   68.000000   18.957000    8.142000

# %%
df.isnull()
# Out:
#      Species  Weight  Length1  Length2  Length3  Height  Width
# 0      False   False    False    False    False   False  False
# 1      False   False    False    False    False   False  False
# 2      False   False    False    False    False   False  False
# 3      False   False    False    False    False   False  False
# 4      False   False    False    False    False   False  False
# ..       ...     ...      ...      ...      ...     ...    ...
# 154    False   False    False    False    False   False  False
# 155    False   False    False    False    False   False  False
# 156    False   False    False    False    False   False  False
# 157    False   False    False    False    False   False  False
# 158    False   False    False    False    False   False  False
#
# [159 rows x 7 columns]

# %%
# df.value_counts("Species == Bream")
# Bream = sns.load_dataset('Bream')

# %%
plt.figure(figsize=(10,6))
# df.plot(kind="bar", x ="Species",y="Height")
sns.violinplot(x='Species',y="Weight" , palette ="husl",data=df)
# Out:
# C:\Users\91742\AppData\Local\Temp\ipykernel_18572\3537998909.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Species',y="Weight" , palette ="husl",data=df)
# <Axes: xlabel='Species', ylabel='Weight'>

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 3
#       1 from sklearn.linear_model import LinearRegression
#       2 regressor = LinearRegression()
# ----> 3 regressor.fit(X_test, y_test)
#
# File c:\Python311\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Python311\Lib\site-packages\sklearn\linear_model\_base.py:609, in LinearRegression.fit(self, X, y, sample_weight)
#     605 n_jobs_ = self.n_jobs
#     607 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# ...

# %%
y_pred = regressor.predict(X_test)

# %%
print(df.head()) 
plt.figure(figsize=(10, 6))
plt.bar(df['Height'], df['Weight'], color = 'blue',linewidth=0.2,width=0.1,edgecolor='b',linestyle=":")
plt.title('Weight vs Height')
plt.xlabel('Height of the fish')
plt.ylabel('Weight of the fish')
plt.show()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
print(df.head()) 
plt.figure(figsize=(10, 6))
plt.bar(df['Height'], df['Width'], color = 'green',linewidth=0.2,width=0.1,edgecolor='b',linestyle=":")
# plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('Weight vs Width')
plt.xlabel('Width of the fish')
plt.ylabel('Weight of the fish')
plt.show()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
