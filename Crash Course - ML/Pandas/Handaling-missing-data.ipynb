# %%
import pandas as pd

csv_1=pd.read_csv("C:\\Users\\91742\\OneDrive\\Desktop\\ds_august\\Pandas\\Test_new2.csv")
print(csv_1)
# Out:
#     Index             Suburb               City  Postcode   Longitude  \
# 0       1       Freemans Bay           Auckland    1011.0  174.748652
# 1       2          Nightcaps          Southland    9630.0  168.028823
# 2       3          Northcote        North Shore     627.0  174.755505
# 3       4           Bay View             Napier    4104.0  176.871662
# 4       5          Parklands       Christchurch    8083.0  172.705997
# 5       6      Hamilton East           Hamilton    3216.0  175.305496
# 6       7           Te Kuiti            Waitomo    3910.0         NaN
# 7       8            Opaheke           Papakura    2113.0  174.947631
# 8       9  North East Valley            Dunedin    9010.0  170.527081
# 9      10         Whangamata  Thames-Coromandel    3620.0  175.883257
# 10     11         Algies Bay             Rodney     920.0  174.745447
# 11     12          Henderson          Waitakere     610.0         NaN
# ...

# %%
print(csv_1.dropna()) #drop the data where some values are mussing
# Out:
#     Index             Suburb           City  Postcode   Longitude   Latitude  \
# 0       1       Freemans Bay       Auckland      1011  174.748652 -36.855732
# 1       2          Nightcaps      Southland      9630  168.028823 -45.970300
# 3       4           Bay View         Napier      4104  176.871662 -39.440389
# 4       5          Parklands   Christchurch      8083  172.705997 -43.472699
# 5       6      Hamilton East       Hamilton      3216  175.305496 -37.781657
# 7       8            Opaheke       Papakura      2113  174.947631 -37.077401
# 8       9  North East Valley        Dunedin      9010  170.527081 -45.846837
# 10     11         Algies Bay         Rodney       920  174.745447 -36.437912
# 12     13            Atawhai         Nelson      7010  173.326718 -41.241585
# 13     14     Pleasant Point         Timaru      7903  171.122902 -44.258881
# 14     15            Frimley       Hastings      4120  176.832406 -39.621293
# ...

# %%
csv_1.dropna(axis=1) #0--> along the row && 1 --> along the columns
# Out:
#     Index             Suburb               City  Postcode  \
# 0       1       Freemans Bay           Auckland      1011
# 1       2          Nightcaps          Southland      9630
# 2       3          Northcote        North Shore       627
# 3       4           Bay View             Napier      4104
# 4       5          Parklands       Christchurch      8083
# 5       6      Hamilton East           Hamilton      3216
# 6       7           Te Kuiti            Waitomo      3910
# 7       8            Opaheke           Papakura      2113
# 8       9  North East Valley            Dunedin      9010
# 9      10         Whangamata  Thames-Coromandel      3620
# 10     11         Algies Bay             Rodney       920
# 11     12          Henderson          Waitakere       610
# 12     13            Atawhai             Nelson      7010
# 13     14     Pleasant Point             Timaru      7903
# 14     15            Frimley           Hastings      4120
# ...

# %%
csv_1.dropna(how="any") # droop all the row where any data is missing
csv_1.dropna(how="all") # NaN show in all function
# Out:
#     Index             Suburb               City  Postcode   Longitude  \
# 0       1       Freemans Bay           Auckland    1011.0  174.748652
# 1       2          Nightcaps          Southland    9630.0  168.028823
# 2       3          Northcote        North Shore     627.0  174.755505
# 3       4           Bay View             Napier    4104.0  176.871662
# 4       5          Parklands       Christchurch    8083.0  172.705997
# 5       6      Hamilton East           Hamilton    3216.0  175.305496
# 6       7           Te Kuiti            Waitomo    3910.0         NaN
# 7       8            Opaheke           Papakura    2113.0  174.947631
# 8       9  North East Valley            Dunedin    9010.0  170.527081
# 9      10         Whangamata  Thames-Coromandel    3620.0  175.883257
# 10     11         Algies Bay             Rodney     920.0  174.745447
# 11     12          Henderson          Waitakere     610.0         NaN
# ...

# %%
csv_1.dropna(subset=["Longitude"]) #remove nan value at specific heading
# Out:
#     Index             Suburb               City  Postcode   Longitude  \
# 0       1       Freemans Bay           Auckland    1011.0  174.748652
# 1       2          Nightcaps          Southland    9630.0  168.028823
# 2       3          Northcote        North Shore     627.0  174.755505
# 3       4           Bay View             Napier    4104.0  176.871662
# 4       5          Parklands       Christchurch    8083.0  172.705997
# 5       6      Hamilton East           Hamilton    3216.0  175.305496
# 7       8            Opaheke           Papakura    2113.0  174.947631
# 8       9  North East Valley            Dunedin    9010.0  170.527081
# 9      10         Whangamata  Thames-Coromandel    3620.0  175.883257
# 10     11         Algies Bay             Rodney     920.0  174.745447
# 12     13            Atawhai             Nelson    7010.0  173.326718
# 14     15            Frimley           Hastings    4120.0  176.832406
# ...

# %%
csv_1.dropna(inplace=True) #drop all nan value row
csv_1
# Out:
#     Index             Suburb           City  Postcode   Longitude   Latitude  \
# 0       1       Freemans Bay       Auckland    1011.0  174.748652 -36.855732
# 1       2          Nightcaps      Southland    9630.0  168.028823 -45.970300
# 3       4           Bay View         Napier    4104.0  176.871662 -39.440389
# 4       5          Parklands   Christchurch    8083.0  172.705997 -43.472699
# 5       6      Hamilton East       Hamilton    3216.0  175.305496 -37.781657
# 7       8            Opaheke       Papakura    2113.0  174.947631 -37.077401
# 8       9  North East Valley        Dunedin    9010.0  170.527081 -45.846837
# 10     11         Algies Bay         Rodney     920.0  174.745447 -36.437912
# 12     13            Atawhai         Nelson    7010.0  173.326718 -41.241585
# 14     15            Frimley       Hastings    4120.0  176.832406 -39.621293
# 15     16        Harrowfield       Hamilton    3210.0  175.266597 -37.742625
# ...

# %%
csv_1.dropna(thresh=1) #remove those row having single non value
# Out:
#     Index             Suburb           City  Postcode   Longitude   Latitude  \
# 0       1       Freemans Bay       Auckland    1011.0  174.748652 -36.855732
# 1       2          Nightcaps      Southland    9630.0  168.028823 -45.970300
# 3       4           Bay View         Napier    4104.0  176.871662 -39.440389
# 4       5          Parklands   Christchurch    8083.0  172.705997 -43.472699
# 5       6      Hamilton East       Hamilton    3216.0  175.305496 -37.781657
# 7       8            Opaheke       Papakura    2113.0  174.947631 -37.077401
# 8       9  North East Valley        Dunedin    9010.0  170.527081 -45.846837
# 10     11         Algies Bay         Rodney     920.0  174.745447 -36.437912
# 12     13            Atawhai         Nelson    7010.0  173.326718 -41.241585
# 14     15            Frimley       Hastings    4120.0  176.832406 -39.621293
# 15     16        Harrowfield       Hamilton    3210.0  175.266597 -37.742625
# ...

# %%
import pandas as pd

csv_1=pd.read_csv("C:\\Users\\91742\\OneDrive\\Desktop\\ds_august\\Pandas\\Test_new2.csv")
print(csv_1)
# Out:
#     Index               City  Postcode   Longitude   Latitude
# 0       1           Auckland    1011.0  174.748652 -36.855732
# 1       2          Southland    9630.0  168.028823 -45.970300
# 2       3        North Shore     627.0  174.755505        NaN
# 3       4             Napier    4104.0  176.871662 -39.440389
# 4       5       Christchurch    8083.0  172.705997 -43.472699
# 5       6           Hamilton    3216.0  175.305496 -37.781657
# 6       7            Waitomo    3910.0         NaN -38.330973
# 7       8           Papakura    2113.0  174.947631 -37.077401
# 8       9            Dunedin    9010.0  170.527081 -45.846837
# 9      10  Thames-Coromandel    3620.0  175.883257        NaN
# 10     11             Rodney     920.0  174.745447 -36.437912
# 11     12          Waitakere     610.0         NaN -36.870359
# 12     13             Nelson    7010.0  173.326718 -41.241585
# 13     14                NaN       NaN         NaN        NaN
# ...

# %%
csv_1.fillna("DAKSH SOOD") #fill the NAN value with the "DAKSH SOOD"

# %%
csv_1.fillna({"City":"DAKSH","Postcode":"sood","Longitude":"DISHU","Latitude":"HARSHU"})
#fill particular heading nan value with given value
# Out:
#     Index               City Postcode   Longitude   Latitude
# 0       1           Auckland   1011.0  174.748652 -36.855732
# 1       2          Southland   9630.0  168.028823   -45.9703
# 2       3        North Shore    627.0  174.755505     HARSHU
# 3       4             Napier   4104.0  176.871662 -39.440389
# 4       5       Christchurch   8083.0  172.705997 -43.472699
# 5       6           Hamilton   3216.0  175.305496 -37.781657
# 6       7            Waitomo   3910.0       DISHU -38.330973
# 7       8           Papakura   2113.0  174.947631 -37.077401
# 8       9            Dunedin   9010.0  170.527081 -45.846837
# 9      10  Thames-Coromandel   3620.0  175.883257     HARSHU
# 10     11             Rodney    920.0  174.745447 -36.437912
# 11     12          Waitakere    610.0       DISHU -36.870359
# 12     13             Nelson   7010.0  173.326718 -41.241585
# 13     14              DAKSH     sood       DISHU     HARSHU
# ...

# %%
csv_1.fillna(method="ffill") #replace nan value with forward filling value
# Out:
# C:\Users\91742\AppData\Local\Temp\ipykernel_5464\1846651122.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   csv_1.fillna(method="ffill")
#     Index               City  Postcode   Longitude   Latitude
# 0       1           Auckland    1011.0  174.748652 -36.855732
# 1       2          Southland    9630.0  168.028823 -45.970300
# 2       3        North Shore     627.0  174.755505 -45.970300
# 3       4             Napier    4104.0  176.871662 -39.440389
# 4       5       Christchurch    8083.0  172.705997 -43.472699
# 5       6           Hamilton    3216.0  175.305496 -37.781657
# 6       7            Waitomo    3910.0  175.305496 -38.330973
# 7       8           Papakura    2113.0  174.947631 -37.077401
# 8       9            Dunedin    9010.0  170.527081 -45.846837
# 9      10  Thames-Coromandel    3620.0  175.883257 -45.846837
# ...

# %%
csv_1.fillna(method="bfill") #backward filling
# Out:
# C:\Users\91742\AppData\Local\Temp\ipykernel_5464\1457547213.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   csv_1.fillna(method="bfill")
#     Index               City  Postcode   Longitude   Latitude
# 0       1           Auckland    1011.0  174.748652 -36.855732
# 1       2          Southland    9630.0  168.028823 -45.970300
# 2       3        North Shore     627.0  174.755505 -39.440389
# 3       4             Napier    4104.0  176.871662 -39.440389
# 4       5       Christchurch    8083.0  172.705997 -43.472699
# 5       6           Hamilton    3216.0  175.305496 -37.781657
# 6       7            Waitomo    3910.0  174.947631 -38.330973
# 7       8           Papakura    2113.0  174.947631 -37.077401
# 8       9            Dunedin    9010.0  170.527081 -45.846837
# 9      10  Thames-Coromandel    3620.0  175.883257 -36.437912
# ...

# %%
csv_1.fillna(method="bfill",axis=1) # see the change in 7index(travel like {<-- <-- <--})
# Out:
# C:\Users\91742\AppData\Local\Temp\ipykernel_5464\19136627.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   csv_1.fillna(method="bfill",axis=1)
# C:\Users\91742\AppData\Local\Temp\ipykernel_5464\19136627.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   csv_1.fillna(method="bfill",axis=1)
#    Index               City Postcode   Longitude   Latitude
# 0      1           Auckland   1011.0  174.748652 -36.855732
# 1      2          Southland   9630.0  168.028823   -45.9703
# 2      3        North Shore    627.0  174.755505        NaN
# 3      4             Napier   4104.0  176.871662 -39.440389
# 4      5       Christchurch   8083.0  172.705997 -43.472699
# ...

# %%
csv_1.fillna(11,inplace=True) #12 is fill at the nan space
csv_1
# Out:
#     Index               City  Postcode   Longitude   Latitude
# 0       1           Auckland    1011.0  174.748652 -36.855732
# 1       2          Southland    9630.0  168.028823 -45.970300
# 2       3        North Shore     627.0  174.755505  12.000000
# 3       4             Napier    4104.0  176.871662 -39.440389
# 4       5       Christchurch    8083.0  172.705997 -43.472699
# 5       6           Hamilton    3216.0  175.305496 -37.781657
# 6       7            Waitomo    3910.0   12.000000 -38.330973
# 7       8           Papakura    2113.0  174.947631 -37.077401
# 8       9            Dunedin    9010.0  170.527081 -45.846837
# 9      10  Thames-Coromandel    3620.0  175.883257  12.000000
# 10     11             Rodney     920.0  174.745447 -36.437912
# 11     12          Waitakere     610.0   12.000000 -36.870359
# 12     13             Nelson    7010.0  173.326718 -41.241585
# 13     14                 12      12.0   12.000000  12.000000
# ...

# %%
csv_1.fillna(10,inplace=True)
csv_1
# Out:
#     Index               City  Postcode   Longitude   Latitude
# 0       1           Auckland    1011.0  174.748652 -36.855732
# 1       2          Southland    9630.0  168.028823 -45.970300
# 2       3        North Shore     627.0  174.755505  12.000000
# 3       4             Napier    4104.0  176.871662 -39.440389
# 4       5       Christchurch    8083.0  172.705997 -43.472699
# 5       6           Hamilton    3216.0  175.305496 -37.781657
# 6       7            Waitomo    3910.0   12.000000 -38.330973
# 7       8           Papakura    2113.0  174.947631 -37.077401
# 8       9            Dunedin    9010.0  170.527081 -45.846837
# 9      10  Thames-Coromandel    3620.0  175.883257  12.000000
# 10     11             Rodney     920.0  174.745447 -36.437912
# 11     12          Waitakere     610.0   12.000000 -36.870359
# 12     13             Nelson    7010.0  173.326718 -41.241585
# 13     14                 12      12.0   12.000000  12.000000
# ...

# %%
print(csv_1.fillna("python",limit=2))
# Out:
#     Index               City  Postcode   Longitude   Latitude
# 0       1           Auckland    1011.0  174.748652 -36.855732
# 1       2          Southland    9630.0  168.028823 -45.970300
# 2       3        North Shore     627.0  174.755505  12.000000
# 3       4             Napier    4104.0  176.871662 -39.440389
# 4       5       Christchurch    8083.0  172.705997 -43.472699
# 5       6           Hamilton    3216.0  175.305496 -37.781657
# 6       7            Waitomo    3910.0   12.000000 -38.330973
# 7       8           Papakura    2113.0  174.947631 -37.077401
# 8       9            Dunedin    9010.0  170.527081 -45.846837
# 9      10  Thames-Coromandel    3620.0  175.883257  12.000000
# 10     11             Rodney     920.0  174.745447 -36.437912
# 11     12          Waitakere     610.0   12.000000 -36.870359
# 12     13             Nelson    7010.0  173.326718 -41.241585
# 13     14                 12      12.0   12.000000  12.000000
# ...

# %%
import pandas as pd

df = pd.read_csv('data.csv')

df.dropna(inplace = True)

print(df.to_string())

#Notice in the result that some rows have been removed (row 18, 22 and 28).

#These rows had cells with empty values.

# %% [markdown]
# Note: Now, the dropna(inplace = True) will NOT return a new DataFrame, but it will remove all rows containing NULL values from the original DataFrame.

# %%
import pandas as pd

df = pd.read_csv('data.csv')

x = df["Calories"].mean() #median and mode

df["Calories"].fillna(x, inplace = True)

print(df.to_string())

#As you can see in row 18 and 28, the empty values from "Calories" was replaced with the mean: 304.68

# %%
import pandas as pd

df = pd.read_csv('data.csv')

x = df["Calories"].mode()[0]

df["Calories"].fillna(x, inplace = True)

print(df.to_string())

#As you can see in row 18 and 28, the empty value from "Calories" was replaced with the mode: 300.0
