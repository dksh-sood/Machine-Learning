# %%
#python number
a =5#int
b =5.5#float
c = 1j #complex
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
import matplotlib.pyplot as plt 
import numpy as np 

xpoints = (1,6,5,7)
ypoints = (5,8,9,6)
plt.plot(xpoints,ypoints, "o")
plt.legend()
plt.show()
# Out:
# C:\Users\91742\AppData\Local\Temp\ipykernel_37596\3444635232.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#list in python
fruits = ['orange','mango','apple']
x,y,z = fruits
print(x)
print(y)
print(z)
# Out:
# orange
# mango
# apple

# %%
a=("hello daksh")
print(a)
print(a[1:3])
print(a[0])
print(a[-1])
print(a[0:7])
result = a[:4] + a[5:]
print(result)
print(a[0::2])#skinp two element due to 2!
print(a.upper())
print(a.lower())
print(a.replace('h','j'))
# Out:
# hello daksh
# el
# h
# h
# hello d
# hell daksh
# hlodkh
# HELLO DAKSH
# hello daksh
# jello daksj

# %%
a="daksh"
b="sood"
c = a+ " " +b
print(c)
print(10>9)#boolean
# Out:
# daksh sood
# True

# %%
#arithmetic operator
a=3
b=4
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a**b)
# Out:
# 7
# -1
# 12
# 0.75
# 3
# 81

# %%
#identity
x=3
y=4
print(x is y)
x is not y
# Out:
# False

# %%
#membership operator -> in , not in
x=["2",3,4,5]
y=2

# %%
#list in python
list1 = [1,"3",3.0,"tarun"]
print(list1[:3])
print(list1[1:])

# print(list1.insert[2,"mango"])
a=['mango','apple','graphes','lichi','orange']
# Out:
# [1, '3', 3.0]
# ['3', 3.0, 'tarun']

# %%
# a=int(input("enter your 1 number:"))
# b=int(input("enter your 2 number:"))

# if(a>b):print("a is greater than b",a & b)
# else:print("b is greater than a",b & a)

# %%
fruits = ["mango","apple","graphes","lichi","orange"]
for x in fruits:
    if x =="apple":
        continue
    print(x)
for x in range(2,6):
    print(x)
# Out:
# mango
# graphes
# lichi
# orange
# 2
# 3
# 4
# 5

# %%
#using of function
def my_func(name):
    print("hello"+ name)
my_func("daksh")
my_func("sood")
# Out:
# hellodaksh
# hellosood
