# %%
import pandas as pd
csv_2=pd.read_csv("C:\\Users\\91742\\OneDrive\\Desktop\\ds_august\\Pandas\\Test_new2.csv")
print(csv_2)
# Out:
#     Index               City  Postcode   Longitude   Latitude
# 0       1           Auckland    1011.0  174.748652 -36.855732
# 1       2          Southland    9630.0  168.028823 -45.970300
# 2       3        North Shore     627.0  174.755505        NaN
# 3       4             Napier    4104.0  176.871662 -39.440389
# 4       5       Christchurch    8083.0  172.705997 -43.472699
# 5       6           Hamilton    3216.0  175.305496 -37.781657
# 6       7            Waitomo    3910.0         NaN -38.330973
# 7       8           Papakura    2113.0  174.947631 -37.077401
# 8       9            Dunedin    9010.0  170.527081 -45.846837
# 9      10  Thames-Coromandel    3620.0  175.883257        NaN
# 10     11             Rodney     920.0  174.745447 -36.437912
# 11     12          Waitakere     610.0         NaN -36.870359
# 12     13             Nelson    7010.0  173.326718 -41.241585
# 13     14                NaN       NaN         NaN        NaN
# ...

# %%
print(csv_2.fillna("python",limit=2)) #fill python upto the limit -->2
# Out:
#     Index               City Postcode   Longitude   Latitude
# 0       1           Auckland   1011.0  174.748652 -36.855732
# 1       2          Southland   9630.0  168.028823   -45.9703
# 2       3        North Shore    627.0  174.755505     python
# 3       4             Napier   4104.0  176.871662 -39.440389
# 4       5       Christchurch   8083.0  172.705997 -43.472699
# 5       6           Hamilton   3216.0  175.305496 -37.781657
# 6       7            Waitomo   3910.0      python -38.330973
# 7       8           Papakura   2113.0  174.947631 -37.077401
# 8       9            Dunedin   9010.0  170.527081 -45.846837
# 9      10  Thames-Coromandel   3620.0  175.883257     python
# 10     11             Rodney    920.0  174.745447 -36.437912
# 11     12          Waitakere    610.0      python -36.870359
# 12     13             Nelson   7010.0  173.326718 -41.241585
# 13     14             python   python         NaN        NaN
# ...

# %%
csv_2.fillna(10,inplace=True)
csv_2
# Out:
#     Index               City  Postcode   Longitude   Latitude
# 0       1           Auckland    1011.0  174.748652 -36.855732
# 1       2          Southland    9630.0  168.028823 -45.970300
# 2       3        North Shore     627.0  174.755505  10.000000
# 3       4             Napier    4104.0  176.871662 -39.440389
# 4       5       Christchurch    8083.0  172.705997 -43.472699
# 5       6           Hamilton    3216.0  175.305496 -37.781657
# 6       7            Waitomo    3910.0   10.000000 -38.330973
# 7       8           Papakura    2113.0  174.947631 -37.077401
# 8       9            Dunedin    9010.0  170.527081 -45.846837
# 9      10  Thames-Coromandel    3620.0  175.883257  10.000000
# 10     11             Rodney     920.0  174.745447 -36.437912
# 11     12          Waitakere     610.0   10.000000 -36.870359
# 12     13             Nelson    7010.0  173.326718 -41.241585
# 13     14                 10      10.0   10.000000  10.000000
# ...

# %% [markdown]
# HANDALING MISSING VALUES (REPLACE AND INTERPOLATE) IN PYTHON PANDAS
# replace -->chnage the particular point

# %%
import pandas as pd
csv_3=pd.read_csv("C:\\Users\\91742\\OneDrive\\Desktop\\ds_august\\Pandas\\Test_new2.csv")
print(csv_3)
# Out:
#     Index               City  Postcode   Longitude   Latitude
# 0       1           Auckland    1011.0  174.748652 -36.855732
# 1       2          Southland    9630.0  168.028823 -45.970300
# 2       3        North Shore     627.0  174.755505        NaN
# 3       4             Napier    4104.0  176.871662 -39.440389
# 4       5       Christchurch    8083.0  172.705997 -43.472699
# 5       6           Hamilton       1.0  175.305496 -37.781657
# 6       7            Waitomo       1.0         NaN -38.330973
# 7       8           Papakura       1.0  174.947631 -37.077401
# 8       9            Dunedin       1.0  170.527081 -45.846837
# 9      10  Thames-Coromandel       1.0  175.883257        NaN
# 10     11             Rodney       1.0  174.745447 -36.437912
# 11     12          Waitakere     610.0         NaN -36.870359
# 12     13             Nelson    7010.0  173.326718 -41.241585
# 13     14                NaN       NaN         NaN        NaN
# ...

# %%
# print(csv_3.replace(to_replace="Southland",value="daksh sood"))
# print(csv_3.replace(to_replace=1,value=69)) 
#replace --> number
# Out:
#     Index               City  Postcode   Longitude   Latitude
# 0     999           Auckland    1011.0  174.748652 -36.855732
# 1     999          Southland    9630.0  168.028823 -45.970300
# 2     999        North Shore     627.0  174.755505        NaN
# 3     999             Napier    4104.0  176.871662 -39.440389
# 4     999       Christchurch    8083.0  172.705997 -43.472699
# 5     999           Hamilton     999.0  175.305496 -37.781657
# 6     999            Waitomo     999.0         NaN -38.330973
# 7     999           Papakura     999.0  174.947631 -37.077401
# 8     999            Dunedin     999.0  170.527081 -45.846837
# 9      10  Thames-Coromandel     999.0  175.883257        NaN
# 10     11             Rodney     999.0  174.745447 -36.437912
# 11     12          Waitakere     610.0         NaN -36.870359
# 12     13             Nelson    7010.0  173.326718 -41.241585
# 13     14                NaN       NaN         NaN        NaN
# ...

# %%
csv_3.replace("[A-Za-z]","DAKSH SOOD",regex=True) #to change all values
# Out:
#     Index                                               City  Postcode  \
# 0       1  DAKSH SOODDAKSH SOODDAKSH SOODDAKSH SOODDAKSH ...    1011.0
# 1       2  DAKSH SOODDAKSH SOODDAKSH SOODDAKSH SOODDAKSH ...    9630.0
# 2       3  DAKSH SOODDAKSH SOODDAKSH SOODDAKSH SOODDAKSH ...     627.0
# 3       4  DAKSH SOODDAKSH SOODDAKSH SOODDAKSH SOODDAKSH ...    4104.0
# 4       5  DAKSH SOODDAKSH SOODDAKSH SOODDAKSH SOODDAKSH ...    8083.0
# 5       6  DAKSH SOODDAKSH SOODDAKSH SOODDAKSH SOODDAKSH ...       1.0
# 6       7  DAKSH SOODDAKSH SOODDAKSH SOODDAKSH SOODDAKSH ...       1.0
# 7       8  DAKSH SOODDAKSH SOODDAKSH SOODDAKSH SOODDAKSH ...       1.0
# 8       9  DAKSH SOODDAKSH SOODDAKSH SOODDAKSH SOODDAKSH ...       1.0
# 9      10  DAKSH SOODDAKSH SOODDAKSH SOODDAKSH SOODDAKSH ...       1.0
# 10     11  DAKSH SOODDAKSH SOODDAKSH SOODDAKSH SOODDAKSH ...       1.0
# 11     12  DAKSH SOODDAKSH SOODDAKSH SOODDAKSH SOODDAKSH ...     610.0
# ...

# %%
csv_3.replace({"City":'[A-Z]'},22, regex=True) #change all the value of particular col
# Out:
# C:\Users\91742\AppData\Local\Temp\ipykernel_14680\2775520036.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   csv_3.replace({"City":'[A-Z]'},22, regex=True)
#     Index  City  Postcode   Longitude   Latitude
# 0       1  22.0    1011.0  174.748652 -36.855732
# 1       2  22.0    9630.0  168.028823 -45.970300
# 2       3  22.0     627.0  174.755505        NaN
# 3       4  22.0    4104.0  176.871662 -39.440389
# 4       5  22.0    8083.0  172.705997 -43.472699
# 5       6  22.0       1.0  175.305496 -37.781657
# 6       7  22.0       1.0         NaN -38.330973
# 7       8  22.0       1.0  174.947631 -37.077401
# 8       9  22.0       1.0  170.527081 -45.846837
# 9      10  22.0       1.0  175.883257        NaN
# ...

# %%
csv_3.replace(1,method="ffill",limit=2,inplace=True) #inpace chnage the original date
# csv_3.replace(1,method="bfill")
csv_3
# Out:
# C:\Users\91742\AppData\Local\Temp\ipykernel_14680\2050383615.py:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   csv_3.replace(1,method="ffill",limit=2,inplace=True)
#     Index               City  Postcode   Longitude   Latitude
# 0       1           Auckland    1011.0  174.748652 -36.855732
# 1       2          Southland    9630.0  168.028823 -45.970300
# 2       3        North Shore     627.0  174.755505        NaN
# 3       4             Napier    4104.0  176.871662 -39.440389
# 4       5       Christchurch    8083.0  172.705997 -43.472699
# 5       6           Hamilton    8083.0  175.305496 -37.781657
# 6       7            Waitomo    8083.0         NaN -38.330973
# 7       8           Papakura    8083.0  174.947631 -37.077401
# 8       9            Dunedin    8083.0  170.527081 -45.846837
# 9      10  Thames-Coromandel       1.0  175.883257        NaN
# ...
