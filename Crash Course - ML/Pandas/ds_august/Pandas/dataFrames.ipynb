# %%
import pandas as pd
#data frames using list
a =[[1,2,3,4,5,6],[11,22,33,44,55,66]]
var = pd.DataFrame(a)
print(var)

# %%
# data frame using dictionary
dict ={"daksh":[1,2,3,4,5],"sood":[6,7,8,9,10],"harsh":[1,2,3,4,5],"mummy":[6,7,8,9,10]} #length must be same
var1 = pd.DataFrame(dict,index=['a','b','c','d','e'])
print(var1)
print(var1["daksh"][3]) #to get any data
print(type(var1))

# %% [markdown]
# rows/columns=["daksh",'harsh']--> used for getting data of particular row and coloumns

# %%
#dataframes by using two series
sr = {"a":pd.Series([1,2,3,4,5]),"b":pd.Series([1,2,3,4,5])}
var3 = pd.DataFrame(sr)
var3 = print(var3)
var3 = print(type(var3))
# Out:
#    a  b
# 0  1  1
# 1  2  2
# 2  3  3
# 3  4  4
# 4  5  5
# <class 'NoneType'>
