# %%
import pandas as pd
var = pd.DataFrame({"A":[1,2,3,4],"B":[5,6,7,8]})
print(var)
var["C"] = var["A"] + var["B"] # arthmetic opt --> (+,-,*,/,%)
print(var)

# %%
#comparision operator
import pandas as pd
var1 = pd.DataFrame({"A":[10,20,30,40],"B":[11,22,33,13]})
var1["python"] =var1["A"] >= 20
var1["python_1"] =var1["B"] <= 30
var1["python_2"] =var1["B"] != 22
print(var1)
# Out:
#     A   B  python  python_1  python_2
# 0  10  11   False      True      True
# 1  20  22    True      True     False
# 2  30  33    True     False      True
# 3  40  13    True      True      True
