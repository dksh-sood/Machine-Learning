# %%
import sea born as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Sea born -->  --> it is used for data visualization  over time or other continuous variable
#               --> advance version of matplotlib
#               --> create plots that can draw relationships between 2 continuous variable

# %%
csv_1 = pd.read_csv("Iris")
