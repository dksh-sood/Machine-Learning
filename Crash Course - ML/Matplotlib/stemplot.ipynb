# %%
import matplotlib.pyplot as plt

x=[1,2,3,4,5,6]
y=[2,2,5,6,4,3]

plt.stem(x,y,linefmt=":",markerfmt="o",bottom=2,basefmt="g",label="python",orientation="vertical") #orentation-->horizontal
#use_line_collection=False(base color change krta hai)
plt.legend()
plt.show()
