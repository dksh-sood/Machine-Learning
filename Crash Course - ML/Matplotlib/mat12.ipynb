# %%
import matplotlib.pyplot as plt
import numpy as np
import random

x=np.random.randint(10,60,(50))
print(x)
# Out:
# [25 26 47 12 35 45 29 10 50 46 17 28 12 29 31 36 56 30 49 17 50 49 41 35
#  12 59 32 23 16 27 14 33 27 56 43 29 23 44 47 40 43 58 19 40 21 41 33 25
#  38 40]

# %%
import matplotlib.pyplot as plt
import numpy as np

no= [50, 56, 39, 34, 58, 17, 13, 12, 20, 31, 55, 53, 57, 34, 38, 39, 54, 28, 53, 56, 21, 34, 33, 46,
 35, 24, 41, 42, 24, 15, 49, 34, 56, 47, 58, 16, 14, 37, 26, 45, 42, 35, 12, 34, 48, 29, 42, 48,
 31, 26,]
a=[10,20,30,40,50,60]
plt.hist(no, color='m',bins=a,edgecolor='black',cumulative=-1,bottom=10,align="left",histtype="step",label="python")
#cumulative frequency down krta h
#histtype = step , filled step , barstacked,bar
#orientaion ="horizontal", vertical
#log=True,, label"python
plt.title("DAKSH SOOD")
plt.xlabel("python")
plt.ylabel("number")
plt.axvline(40,color='r',label="line")
plt.grid()
plt.legend()
plt.show()
